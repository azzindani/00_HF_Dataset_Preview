# %% [markdown]
# <a href="https://colab.research.google.com/github/azzindani/00_HF_Dataset_Preview/blob/main/HF_Synth_APIGen_v0_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Modules

# %%
# !pip install datasets

# %%
from datasets import load_dataset
from datasets import Dataset

# %% [markdown]
# ## Import Dataset

# %%
#url = 'https://huggingface.co/datasets/KingNish/reasoning-base-20k'
#dataset_name = url.split('datasets/')[-1]

dataset_name = 'argilla/Synth-APIGen-v0.1'

# %%
dataset = load_dataset(dataset_name)
# Out:
# README.md:   0%|          | 0.00/9.23k [00:00<?, ?B/s]
# train-00000-of-00001.parquet:   0%|          | 0.00/29.7M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/49402 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['func_name', 'func_desc', 'tools', 'query', 'answers', 'model_name', 'hash_id'],
#         num_rows: 49402
#     })
# })

# %%
dataset['train'].select(range(50)).to_pandas().head(50)
# Out:
#                                         func_name  \
# 0                                number_to_binary
# 1                      make_dict_from_keys_values
# 2                        compute_total_resistance
# 3                           cartesian_to_polar_2D
# 4                                 insert_position
# 5                                  parse_taxonomy
# 6                           replace_country_names
# 7                               generate_integers
# 8                                     pair_encode
# 9                                    get_temp_str
# 10                      find_first_available_port
# 11                             process_json_files
# 12                                    sqrt_approx
# 13                               get_order_status
# 14                      int_array_to_binary_array
# 15                                  parse_records
# 16                                   top_5_values
# 17                       process_rectangle_tuples
# ...

# %%
dataset = dataset['train'].train_test_split(test_size = 0.1, seed = 42)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['func_name', 'func_desc', 'tools', 'query', 'answers', 'model_name', 'hash_id'],
#         num_rows: 44461
#     })
#     test: Dataset({
#         features: ['func_name', 'func_desc', 'tools', 'query', 'answers', 'model_name', 'hash_id'],
#         num_rows: 4941
#     })
# })

# %%
train_dataset = dataset['train']
test_dataset = dataset['test']
train_dataset
# Out:
# Dataset({
#     features: ['func_name', 'func_desc', 'tools', 'query', 'answers', 'model_name', 'hash_id'],
#     num_rows: 44461
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['func_name', 'func_desc', 'tools', 'query', 'answers', 'model_name', 'hash_id'],
#     num_rows: 4941
# })

# %%
dataset['train'][0]
# Out:
# {'func_name': 'dump_dict_to_file',
#  'func_desc': 'Dumps a dictionary into a human-readable JSON file.',
#  'tools': '[{"type":"function","function":{"name":"dump_dict_to_file","description":"Dumps a dictionary into a human-readable JSON file.","parameters":{"type":"object","properties":{"dictionary":{"type":"object","description":"The dictionary to be dumped."},"filename":{"type":"string","description":"The name of the file where the dictionary will be dumped."}},"required":["dictionary","filename"]}}}]',
#  'query': "Save the user's information into a file named user_data.json, where the data includes name, age, and occupation. Also, save the product details into a file named product_info.json, which contains the product name, price, and quantity.",
# ...
