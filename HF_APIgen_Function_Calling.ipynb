# %% [markdown]
# <a href="https://colab.research.google.com/github/azzindani/00_HF_Dataset_Preview/blob/main/HF_APIgen_Function_Calling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Modules

# %%
# !pip install datasets

# %%
from datasets import load_dataset
from datasets import Dataset

# %% [markdown]
# ## Import Dataset

# %%
#url = 'https://huggingface.co/datasets/KingNish/reasoning-base-20k'
#dataset_name = url.split('datasets/')[-1]

dataset_name = 'argilla/apigen-function-calling'

# %%
dataset = load_dataset(dataset_name)

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['answers', 'query', 'id', 'tools', 'func_name', 'func_desc', 'hash_id', 'model_name', 'origin'],
#         num_rows: 109402
#     })
# })

# %%
dataset['train'].select(range(50)).to_pandas().head(50)
# Out:
#                                               answers  \
# 0   [{"name": "live_giveaways_by_type", "arguments...
# 1   [{"name": "web_chain_details", "arguments": {"...
# 2   [{"name": "t3ma", "arguments": {"symbol": "ETH...
# 3   [{"name": "list_titles", "arguments": {"networ...
# 4   [{"name": "stagecompetitorstandings", "argumen...
# 5   [{"name": "product_id", "arguments": {"is_id":...
# 6   [{"name": "get_id", "arguments": {"q": "Pulp F...
# 7   [{"name": "time_zone_api", "arguments": {"q": ...
# 8   [{"name": "find_peak_element", "arguments": {"...
# 9   [{"name": "availability", "arguments": {"url":...
# 10  [{"name": "poor_backlinks", "arguments": {"dom...
# 11  [{"name": "auto_complete_deprecating", "argume...
# 12  [{"name": "matchschedules", "arguments": {"day...
# 13  [{"name": "place_safeway_order", "arguments": ...
# 14  [{"name": "get_search_user", "arguments": {"is...
# 15  [{"name": "get_post", "arguments": {"aweme_id"...
# ...

# %%
dataset = dataset['train'].train_test_split(test_size = 0.1, seed = 42)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['answers', 'query', 'id', 'tools', 'func_name', 'func_desc', 'hash_id', 'model_name', 'origin'],
#         num_rows: 98461
#     })
#     test: Dataset({
#         features: ['answers', 'query', 'id', 'tools', 'func_name', 'func_desc', 'hash_id', 'model_name', 'origin'],
#         num_rows: 10941
#     })
# })

# %%
train_dataset = dataset['train']
test_dataset = dataset['test']
train_dataset
# Out:
# Dataset({
#     features: ['answers', 'query', 'id', 'tools', 'func_name', 'func_desc', 'hash_id', 'model_name', 'origin'],
#     num_rows: 98461
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['answers', 'query', 'id', 'tools', 'func_name', 'func_desc', 'hash_id', 'model_name', 'origin'],
#     num_rows: 10941
# })

# %%
dataset['train'][0]
# Out:
# {'answers': '[{"name": "get_range", "arguments": {"start": 10, "end": 20}}]',
#  'query': 'Format the range from 10 to 20.',
#  'id': 18199,
# ...
