# %% [markdown]
# <a href="https://colab.research.google.com/github/azzindani/00_HF_Dataset_Preview/blob/main/HF_Dataset_Medical_Symptom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Modules

# %%
# !pip install datasets

# %%
from datasets import load_dataset
from datasets import Dataset

# %% [markdown]
# ## Import Dataset

# %%
#url = 'https://huggingface.co/datasets/KingNish/reasoning-base-20k'
#dataset_name = url.split('datasets/')[-1]

dataset_name = 'mohammad2928git/complete_medical_symptom_dataset'

# %%
dataset = load_dataset(dataset_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/776 [00:00<?, ?B/s]
# train-00000-of-00004.parquet:   0%|          | 0.00/81.3M [00:00<?, ?B/s]
# train-00001-of-00004.parquet:   0%|          | 0.00/82.7M [00:00<?, ?B/s]
# train-00002-of-00004.parquet:   0%|          | 0.00/83.1M [00:00<?, ?B/s]
# train-00003-of-00004.parquet:   0%|          | 0.00/76.7M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1300022 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'symptoms', 'lebel_text', 'Code', 'Name', 'Symptoms', 'Treatments', 'AGE', 'DIFFERENTIAL_DIAGNOSIS', 'SEX', 'PATHOLOGY', 'EVIDENCES', 'INITIAL_EVIDENCE'],
#         num_rows: 1300022
#     })
# })

# %%
dataset['train'].select(range(50)).to_pandas().head(50)
# Out:
#                                                  text  label  \
# 0   I have been having migraines and headaches. I ...    308
# 1   I have asthma and I get wheezing and breathing...     35
# 2   Signs and symptoms of primary ovarian insuffic...    798
# 3   cough,high_fever,breathlessness,family_history...    149
# 4   chills,vomiting,high_fever,sweating,headache,n...    596
# 5   Posterior cortical atrophy symptoms vary among...    785
# 6   I've been having back pain, a cough, and numbn...    186
# 7   yellowish_skin,nausea,loss_of_appetite,yellowi...    466
# 8   joint_pain,neck_pain,knee_pain,hip_joint_pain,...    700
# 9   An unusual sensation (aura) may precede a temp...    971
# 10  vomiting,yellowish_skin,abdominal_pain,swellin...     33
# 11  vomiting,fatigue,anxiety,sweating,headache,nau...    504
# 12  fatigue,mood_swings,weight_loss,restlessness,s...    502
# 13  joint_pain,vomiting,yellowish_skin,dark_urine,...    464
# ...

# %%
dataset = dataset['train'].train_test_split(test_size = 0.1, seed = 42)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'label', 'symptoms', 'lebel_text', 'Code', 'Name', 'Symptoms', 'Treatments', 'AGE', 'DIFFERENTIAL_DIAGNOSIS', 'SEX', 'PATHOLOGY', 'EVIDENCES', 'INITIAL_EVIDENCE'],
#         num_rows: 1170019
#     })
#     test: Dataset({
#         features: ['text', 'label', 'symptoms', 'lebel_text', 'Code', 'Name', 'Symptoms', 'Treatments', 'AGE', 'DIFFERENTIAL_DIAGNOSIS', 'SEX', 'PATHOLOGY', 'EVIDENCES', 'INITIAL_EVIDENCE'],
#         num_rows: 130003
#     })
# })

# %%
train_dataset = dataset['train']
test_dataset = dataset['test']
train_dataset
# Out:
# Dataset({
#     features: ['text', 'label', 'symptoms', 'lebel_text', 'Code', 'Name', 'Symptoms', 'Treatments', 'AGE', 'DIFFERENTIAL_DIAGNOSIS', 'SEX', 'PATHOLOGY', 'EVIDENCES', 'INITIAL_EVIDENCE'],
#     num_rows: 1170019
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['text', 'label', 'symptoms', 'lebel_text', 'Code', 'Name', 'Symptoms', 'Treatments', 'AGE', 'DIFFERENTIAL_DIAGNOSIS', 'SEX', 'PATHOLOGY', 'EVIDENCES', 'INITIAL_EVIDENCE'],
#     num_rows: 130003
# })

# %%
dataset['train'][0]
# Out:
# {'text': None,
#  'label': None,
#  'symptoms': ['pericarditis',
#   'pain reason consulting',
#   'characterize pain:',
#   'characterize pain:',
#   'feel pain',
#   'feel pain',
#   'feel pain',
#   'feel pain',
#   'feel pain',
#   'intense pain',
#   'pain radiate location',
#   'precisely pain located',
#   'fast pain',
#   'experiencing shortness breath difficulty breathing significant way',
#   'smoke cigarettes',
#   'constantly feel fatigued non-restful sleep',
#   'consulting high blood pressure',
#   'lesions redness problems skin believe condition consulting',
#   'color rash',
#   'lesions peel',
#   'rash swollen',
#   'affected region located',
#   'affected region located',
#   'affected region located',
#   'lesion lesions larger 1cm',
#   'severe itching',
#   'first menstrual period age 12',
#   'traveled country last 4 weeks',
#   'painful mouth ulcers sores'],
#  'lebel_text': ['sle',
#   'acute pulmonary edema',
#   'unstable angina',
# ...
