# %% [markdown]
# <a href="https://colab.research.google.com/github/azzindani/00_HF_Dataset_Preview/blob/main/HF_Enron_Aeslc_Emails.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Modules

# %%
# !pip install datasets

# %%
from datasets import load_dataset
from datasets import Dataset

# %% [markdown]
# ## Import Dataset

# %%
#url = 'https://huggingface.co/datasets/KingNish/reasoning-base-20k'
#dataset_name = url.split('datasets/')[-1]

dataset_name = 'snoop2head/enron_aeslc_emails'

# %%
dataset = load_dataset(dataset_name)
# Out:
# dataset_infos.json:   0%|          | 0.00/780 [00:00<?, ?B/s]
# (…)-00000-of-00003-e84eb6663f20c00e.parquet:   0%|          | 0.00/202M [00:00<?, ?B/s]
# (…)-00001-of-00003-1b1300ac770ec5ec.parquet:   0%|          | 0.00/177M [00:00<?, ?B/s]
# (…)-00002-of-00003-d94747ba7d786cc1.parquet:   0%|          | 0.00/147M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/535703 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 535703
#     })
# })

# %%
dataset['train'].select(range(50)).to_pandas().head(50)
# Out:
#                                                  text
# 0   Date: Mon, 14 May 2001 16:39:00 -0700 (PDT)\nF...
# 1   Date: Fri, 4 May 2001 13:51:00 -0700 (PDT)\nFr...
# 2   Date: Wed, 18 Oct 2000 03:00:00 -0700 (PDT)\nF...
# 3   Date: Mon, 23 Oct 2000 06:13:00 -0700 (PDT)\nF...
# 4   Date: Thu, 31 Aug 2000 05:07:00 -0700 (PDT)\nF...
# 5   Date: Thu, 31 Aug 2000 04:17:00 -0700 (PDT)\nF...
# 6   Date: Tue, 22 Aug 2000 07:44:00 -0700 (PDT)\nF...
# 7   Date: Fri, 14 Jul 2000 06:59:00 -0700 (PDT)\nF...
# 8   Date: Tue, 17 Oct 2000 02:26:00 -0700 (PDT)\nF...
# 9   Date: Mon, 16 Oct 2000 06:44:00 -0700 (PDT)\nF...
# 10  Date: Mon, 16 Oct 2000 06:42:00 -0700 (PDT)\nF...
# 11  Date: Fri, 13 Oct 2000 06:45:00 -0700 (PDT)\nF...
# 12  Date: Mon, 9 Oct 2000 07:16:00 -0700 (PDT)\nFr...
# 13  Date: Mon, 9 Oct 2000 07:00:00 -0700 (PDT)\nFr...
# 14  Date: Thu, 5 Oct 2000 06:26:00 -0700 (PDT)\nFr...
# 15  Date: Thu, 5 Oct 2000 05:55:00 -0700 (PDT)\nFr...
# ...

# %%
dataset = dataset['train'].train_test_split(test_size = 0.1, seed = 42)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text'],
#         num_rows: 482132
#     })
#     test: Dataset({
#         features: ['text'],
#         num_rows: 53571
#     })
# })

# %%
train_dataset = dataset['train']
test_dataset = dataset['test']
train_dataset
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 482132
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 53571
# })

# %%
dataset['train'][0]
# Out:
# {'text': 'Date: Wed, 16 Aug 2000 05:22:00 -0700 (PDT)\nFrom: robert.bruce@enron.com\nTo: mark.taylor@enron.com\nSubject: status report\nBody: \nCc: sara.shackleton@enron.com\nBcc: sara.shackleton@enron.com\nMark, please let me know if this format suffices -- if so I will update this \nfor you every Monday -- thanks, Bob'}
