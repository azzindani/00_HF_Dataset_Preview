# %% [markdown]
# <a href="https://colab.research.google.com/github/azzindani/00_HF_Dataset_Preview/blob/main/HF_Enron_Emails_Parsed.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Modules

# %%
# !pip install datasets

# %%
from datasets import load_dataset
from datasets import Dataset

# %% [markdown]
# ## Import Dataset

# %%
#url = 'https://huggingface.co/datasets/KingNish/reasoning-base-20k'
#dataset_name = url.split('datasets/')[-1]

dataset_name = 'Hellisotherpeople/enron_emails_parsed'

# %%
dataset = load_dataset(dataset_name)
# Out:
# emails_parsed.parquet:   0%|          | 0.00/676M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/535703 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['date', 'from', 'to', 'subject', 'body'],
#         num_rows: 535703
#     })
# })

# %%
dataset['train'].select(range(50)).to_pandas().head(50)
# Out:
#                                      date                     from  \
# 0   Mon, 14 May 2001 16:39:00 -0700 (PDT)  phillip.allen@enron.com
# 1    Fri, 4 May 2001 13:51:00 -0700 (PDT)  phillip.allen@enron.com
# 2   Wed, 18 Oct 2000 03:00:00 -0700 (PDT)  phillip.allen@enron.com
# 3   Mon, 23 Oct 2000 06:13:00 -0700 (PDT)  phillip.allen@enron.com
# 4   Thu, 31 Aug 2000 05:07:00 -0700 (PDT)  phillip.allen@enron.com
# 5   Thu, 31 Aug 2000 04:17:00 -0700 (PDT)  phillip.allen@enron.com
# 6   Tue, 22 Aug 2000 07:44:00 -0700 (PDT)  phillip.allen@enron.com
# 7   Fri, 14 Jul 2000 06:59:00 -0700 (PDT)  phillip.allen@enron.com
# 8   Tue, 17 Oct 2000 02:26:00 -0700 (PDT)  phillip.allen@enron.com
# 9   Mon, 16 Oct 2000 06:44:00 -0700 (PDT)  phillip.allen@enron.com
# 10  Mon, 16 Oct 2000 06:42:00 -0700 (PDT)  phillip.allen@enron.com
# 11  Fri, 13 Oct 2000 06:45:00 -0700 (PDT)  phillip.allen@enron.com
# 12   Mon, 9 Oct 2000 07:16:00 -0700 (PDT)  phillip.allen@enron.com
# ...

# %%
dataset = dataset['train'].train_test_split(test_size = 0.1, seed = 42)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['date', 'from', 'to', 'subject', 'body'],
#         num_rows: 482132
#     })
#     test: Dataset({
#         features: ['date', 'from', 'to', 'subject', 'body'],
#         num_rows: 53571
#     })
# })

# %%
train_dataset = dataset['train']
test_dataset = dataset['test']
train_dataset
# Out:
# Dataset({
#     features: ['date', 'from', 'to', 'subject', 'body'],
#     num_rows: 482132
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['date', 'from', 'to', 'subject', 'body'],
#     num_rows: 53571
# })

# %%
dataset['train'][0]
# Out:
# {'date': 'Wed, 16 Aug 2000 05:22:00 -0700 (PDT)',
#  'from': 'robert.bruce@enron.com',
#  'to': 'mark.taylor@enron.com',
#  'subject': 'status report',
#  'body': ' Cc: sara.shackleton@enron.com Bcc: sara.shackleton@enron.com Mark, please let me know if this format suffices -- if so I will update this for you every Monday -- thanks, Bob'}
