# %% [markdown]
# <a href="https://colab.research.google.com/github/azzindani/00_HF_Dataset_Preview/blob/main/HF_CENSUS_NER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Modules

# %%
# !pip install datasets

# %%
from datasets import load_dataset
from datasets import Dataset

# %% [markdown]
# ## Import Dataset

# %%
#url = 'https://huggingface.co/datasets/KingNish/reasoning-base-20k'
#dataset_name = url.split('datasets/')[-1]

dataset_name = 'Josephgflowers/CENSUS-NER-Name-Email-Address-Phone'

# %%
dataset = load_dataset(dataset_name)
# Out:
# README.md:   0%|          | 0.00/3.59k [00:00<?, ?B/s]
# (…)CSA_CENSUS1_2016Sep_formatted_output.csv:   0%|          | 0.00/662M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/1048575 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['system', 'user', 'assistant'],
#         num_rows: 1048575
#     })
# })

# %%
dataset['train'].select(range(50)).to_pandas().head(50)
# Out:
#                                                system  \
# 0   Extract the following information from the use...
# 1   Extract the following information from the use...
# 2   Extract the following information from the use...
# 3   Extract the following information from the use...
# 4   Extract the following information from the use...
# 5   Extract the following information from the use...
# 6   Extract the following information from the use...
# 7   Extract the following information from the use...
# 8   Extract the following information from the use...
# 9   Extract the following information from the use...
# 10  Extract the following information from the use...
# 11  Extract the following information from the use...
# 12  Extract the following information from the use...
# 13  Extract the following information from the use...
# 14  Extract the following information from the use...
# 15  Extract the following information from the use...
# ...

# %%
dataset = dataset['train'].train_test_split(test_size = 0.1, seed = 42)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['system', 'user', 'assistant'],
#         num_rows: 943717
#     })
#     test: Dataset({
#         features: ['system', 'user', 'assistant'],
#         num_rows: 104858
#     })
# })

# %%
train_dataset = dataset['train']
test_dataset = dataset['test']
train_dataset
# Out:
# Dataset({
#     features: ['system', 'user', 'assistant'],
#     num_rows: 943717
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['system', 'user', 'assistant'],
#     num_rows: 104858
# })

# %%
dataset['train'][0]
# Out:
# {'system': "Extract the following information from the user input: Name, Email, Phone number, and Address. If a field is missing, ignore it and don't output anything regarding this field. Return the answer in JSON format.",
#  'user': 'HERLING CONSTRUCTION INC, HERLINGCORP@AOL.COM, (951) 845-9600, 635 VIELE AVE UNIT A, BEAUMONT, CA, 92223, US. Extra Info: 1151655, nan, A, N, N, 33562 YUCAIPA BLVD #4-442, YUCAIPA, CA, 92399, US, (951) 845-9696, 22-SEP-15, 100.0, 2014.0, 16-JUL-03, CA, 1.0, 1.0',
#  'assistant': '{\n  "name": "HERLING CONSTRUCTION INC",\n  "email": "HERLINGCORP@AOL.COM",\n  "phone_number": "(951) 845-9600",\n  "address": "635 VIELE AVE UNIT A, BEAUMONT, CA, 92223, US"\n}'}
