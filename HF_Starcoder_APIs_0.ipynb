# %% [markdown]
# <a href="https://colab.research.google.com/github/azzindani/00_HF_Dataset_Preview/blob/main/HF_Starcoder_APIs_0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Modules

# %%
# !pip install datasets

# %%
from datasets import load_dataset
from datasets import Dataset

# %% [markdown]
# ## Import Dataset

# %%
#url = 'https://huggingface.co/datasets/KingNish/reasoning-base-20k'
#dataset_name = url.split('datasets/')[-1]

dataset_name = 'adalib/starcoder-apis-0'

# %%
dataset = load_dataset(dataset_name)
# Out:
# README.md:   0%|          | 0.00/364 [00:00<?, ?B/s]
# ...
# Resolving data files:   0%|          | 0/26 [00:00<?, ?it/s]
# ...
# train-00000-of-00026.parquet:   0%|          | 0.00/177M [00:00<?, ?B/s]
# train-00001-of-00026.parquet:   0%|          | 0.00/172M [00:00<?, ?B/s]
# train-00002-of-00026.parquet:   0%|          | 0.00/172M [00:00<?, ?B/s]
# train-00003-of-00026.parquet:   0%|          | 0.00/174M [00:00<?, ?B/s]
# train-00004-of-00026.parquet:   0%|          | 0.00/170M [00:00<?, ?B/s]
# train-00005-of-00026.parquet:   0%|          | 0.00/176M [00:00<?, ?B/s]
# train-00006-of-00026.parquet:   0%|          | 0.00/176M [00:00<?, ?B/s]
# train-00007-of-00026.parquet:   0%|          | 0.00/174M [00:00<?, ?B/s]
# train-00008-of-00026.parquet:   0%|          | 0.00/176M [00:00<?, ?B/s]
# train-00009-of-00026.parquet:   0%|          | 0.00/177M [00:00<?, ?B/s]
# train-00010-of-00026.parquet:   0%|          | 0.00/169M [00:00<?, ?B/s]
# ...

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['code', 'apis', 'extract_api'],
#         num_rows: 1589922
#     })
# })

# %%
dataset['train'].select(range(50)).to_pandas().head(50)
# Out:
#                                                  code  \
# 0   from django.contrib import admin\nfrom .models...
# 1   import asyncio\nimport os\nimport tempfile\nfr...
# 2   #!/usr/bin/env python\n# -*- coding:utf-8 -*-\...
# 3   # -*- coding: utf-8 -*-\n#  coding=utf-8\nimpo...
# 4   """Forms for RTD donations"""\n\nimport loggin...
# 5   #!/usr/bin/env python\n# -*- coding: utf-8 -*-...
# 6   from django.db.models import Q\n\nfrom django....
# 7   ##############################################...
# 8   from zeit.cms.i18n import MessageFactory as _\...
# 9   import imtreat\n\nimg = imtreat.imageManagerCl...
# 10  import requests\n\nwords_list = requests.get("...
# 11  import unittest\nfrom unittest import mock\nim...
# 12  # Copyright The PyTorch Lightning team.\n#\n# ...
# 13  #\n# Copyright (c) 2021 The GPflux Contributor...
# 14  from floodsystem.stationdata import build_stat...
# 15  import logging\nimport time\nfrom datetime imp...
# ...

# %%
dataset = dataset['train'].train_test_split(test_size = 0.1, seed = 42)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['code', 'apis', 'extract_api'],
#         num_rows: 1430929
#     })
#     test: Dataset({
#         features: ['code', 'apis', 'extract_api'],
#         num_rows: 158993
#     })
# })

# %%
train_dataset = dataset['train']
test_dataset = dataset['test']
train_dataset
# Out:
# Dataset({
#     features: ['code', 'apis', 'extract_api'],
#     num_rows: 1430929
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['code', 'apis', 'extract_api'],
#     num_rows: 158993
# })

# %%
dataset['train'][0]
# Out:
# {'code': "from pyconvcli import PyConvCli\nimport os\n\ndef main():\n    cli = PyConvCli('test_pyconvcli_internal_cli',os.path.dirname(os.path.realpath(__file__)),'pyconvcli-test')\n    cli.run()\n\ndef visualize():\n    cli= PyConvCli('test_pyconvcli_internal_cli',os.path.dirname(os.path.realpath(__file__)),'pyconvcli-test')\n    args,parsers = cli.parse_args()\n    cli.parsers=parsers\n    cli.visualize()",
#  'apis': ['os.path.realpath'],
#  'extract_api': "[((121, 147), 'os.path.realpath', 'os.path.realpath', (['__file__'], {}), '(__file__)\\n', (137, 147), False, 'import os\\n'), ((264, 290), 'os.path.realpath', 'os.path.realpath', (['__file__'], {}), '(__file__)\\n', (280, 290), False, 'import os\\n')]"}
