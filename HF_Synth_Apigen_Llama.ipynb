# %% [markdown]
# <a href="https://colab.research.google.com/github/azzindani/00_HF_Dataset_Preview/blob/main/HF_Synth_Apigen_Llama.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Modules

# %%
# !pip install datasets

# %%
from datasets import load_dataset
from datasets import Dataset

# %% [markdown]
# ## Import Dataset

# %%
#url = 'https://huggingface.co/datasets/KingNish/reasoning-base-20k'
#dataset_name = url.split('datasets/')[-1]

dataset_name = 'argilla-warehouse/synth-apigen-llama'

# %%
dataset = load_dataset(dataset_name)

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['func_name', 'func_desc', 'tools', 'examples', 'query', 'answers', 'distilabel_metadata', 'model_name', 'keep_row_after_execution_check', 'execution_result', 'thought', 'keep_row_after_semantic_check'],
#         num_rows: 40028
#     })
# })

# %%
dataset['train'].select(range(50)).to_pandas().head(50)
# Out:
#                         func_name  \
# 0                       get_value
# 1                 check_collision
# 2                       serialize
# 3                   get_submatrix
# 4                      matrix_sum
# 5               extract_id_values
# 6                    sort_strings
# 7        generate_pascal_triangle
# 8               decimal_to_binary
# 9             factorial_recursive
# 10                    modify_list
# 11                    encode_list
# 12               append_docstring
# 13           transform_dictionary
# 14                  unwrap_string
# 15         sum_of_natural_numbers
# 16           numerical_difference
# 17              generate_username
# 18                       sum_dict
# 19                  reverse_words
# 20              get_all_employees
# 21                  calculate_iou
# 22               initialize_table
# 23                  set_threshold
# 24                   remove_empty
# 25                  convert_names
# ...

# %%
dataset = dataset['train'].train_test_split(test_size = 0.1, seed = 42)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['func_name', 'func_desc', 'tools', 'examples', 'query', 'answers', 'distilabel_metadata', 'model_name', 'keep_row_after_execution_check', 'execution_result', 'thought', 'keep_row_after_semantic_check'],
#         num_rows: 36025
#     })
#     test: Dataset({
#         features: ['func_name', 'func_desc', 'tools', 'examples', 'query', 'answers', 'distilabel_metadata', 'model_name', 'keep_row_after_execution_check', 'execution_result', 'thought', 'keep_row_after_semantic_check'],
#         num_rows: 4003
#     })
# })

# %%
train_dataset = dataset['train']
test_dataset = dataset['test']
train_dataset
# Out:
# Dataset({
#     features: ['func_name', 'func_desc', 'tools', 'examples', 'query', 'answers', 'distilabel_metadata', 'model_name', 'keep_row_after_execution_check', 'execution_result', 'thought', 'keep_row_after_semantic_check'],
#     num_rows: 36025
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['func_name', 'func_desc', 'tools', 'examples', 'query', 'answers', 'distilabel_metadata', 'model_name', 'keep_row_after_execution_check', 'execution_result', 'thought', 'keep_row_after_semantic_check'],
#     num_rows: 4003
# })

# %%
dataset['train'][0]
# Out:
# {'func_name': 'check_duplicate',
#  'func_desc': 'Checks if a list contains any duplicate elements.',
#  'tools': '[{"type": "function", "function": {"name": "check_duplicate", "description": "Checks if a list contains any duplicate elements.", "parameters": {"type": "object", "properties": {"lst": {"type": "array", "items": {"type": "integer"}, "description": "A list of integers to check for duplicates."}}, "required": ["lst"]}}}]',
# ...
