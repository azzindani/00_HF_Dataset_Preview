# %% [markdown]
# <a href="https://colab.research.google.com/github/azzindani/00_HF_Dataset_Preview/blob/main/HF_Dataset_Finance_Alpaca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Modules

# %%
# !pip install datasets

# %%
from datasets import load_dataset
from datasets import Dataset

# %% [markdown]
# ## Import Dataset

# %%
#url = 'https://huggingface.co/datasets/KingNish/reasoning-base-20k'
#dataset_name = url.split('datasets/')[-1]

dataset_name = 'gbharti/finance-alpaca'

# %%
dataset = load_dataset(dataset_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/709 [00:00<?, ?B/s]
# Cleaned_date.json:   0%|          | 0.00/42.9M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/68912 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'instruction', 'input', 'output'],
#         num_rows: 68912
#     })
# })

# %%
dataset['train'].select(range(50)).to_pandas().head(50)
# Out:
#    text                                        instruction input  \
# 0        For a car, what scams can be plotted with 0% f...
# 1        Why does it matter if a Central Bank has a neg...
# 2                    Where should I be investing my money?
# 3                     Specifically when do options expire?
# 4        Negative Balance from Automatic Options Exerci...
# 5        Approximation of equity value for company in d...
# 6        Is it true that 90% of investors lose their mo...
# 7        Can a company charge you for services never re...
# 8        Working out if I should be registered as self-...
# 9                                  About eToro investments
# 10       Pay off car loan entirely or leave $1 until th...
# 11       Including the region where you live in your in...
# 12       Are there any rules against penalizing consume...
# 13       What are the reasons to get more than one cred...
# 14                    Why is economic growth so important?
# ...

# %%
dataset = dataset['train'].train_test_split(test_size = 0.1, seed = 42)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'instruction', 'input', 'output'],
#         num_rows: 62020
#     })
#     test: Dataset({
#         features: ['text', 'instruction', 'input', 'output'],
#         num_rows: 6892
#     })
# })

# %%
train_dataset = dataset['train']
test_dataset = dataset['test']
train_dataset
# Out:
# Dataset({
#     features: ['text', 'instruction', 'input', 'output'],
#     num_rows: 62020
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['text', 'instruction', 'input', 'output'],
#     num_rows: 6892
# })

# %%
dataset['train'][0]
# Out:
# {'text': '',
#  'instruction': 'Analyze the way the American media portrays politics.',
#  'input': '',
#  'output': 'The American media generally portrays politics in a negative light. News coverage is often focused on the negative aspects of politics and the political process. It often ignores the positive impacts of policy decisions and tends to distort the actual picture of politics – often displaying it as a circus of corruption and dysfunction. This depiction of politics can be damaging, as it encourages citizens to think of politicians and those in power as adversaries rather than potential partners or problem solvers.'}
