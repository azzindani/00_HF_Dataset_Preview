# %% [markdown]
# <a href="https://colab.research.google.com/github/azzindani/00_HF_Dataset_Preview/blob/main/HF_Dataset_OpenAI_MMMLU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Modules

# %%
# !pip install datasets

# %%
from datasets import load_dataset
from datasets import Dataset

# %% [markdown]
# ## Import Dataset

# %%
#url = 'https://huggingface.co/datasets/KingNish/reasoning-base-20k'
#dataset_name = url.split('datasets/')[-1]

dataset_name = 'openai/MMMLU'

# %%
dataset = load_dataset(dataset_name)
# Out:
# README.md:   0%|          | 0.00/3.01k [00:00<?, ?B/s]
# test/mmlu_AR-XY.csv:   0%|          | 0.00/9.83M [00:00<?, ?B/s]
# mmlu_BN-BD.csv:   0%|          | 0.00/16.3M [00:00<?, ?B/s]
# test/mmlu_DE-DE.csv:   0%|          | 0.00/7.81M [00:00<?, ?B/s]
# test/mmlu_ES-LA.csv:   0%|          | 0.00/7.64M [00:00<?, ?B/s]
# test/mmlu_FR-FR.csv:   0%|          | 0.00/8.11M [00:00<?, ?B/s]
# mmlu_HI-IN.csv:   0%|          | 0.00/16.2M [00:00<?, ?B/s]
# test/mmlu_ID-ID.csv:   0%|          | 0.00/7.11M [00:00<?, ?B/s]
# test/mmlu_IT-IT.csv:   0%|          | 0.00/7.60M [00:00<?, ?B/s]
# test/mmlu_JA-JP.csv:   0%|          | 0.00/8.02M [00:00<?, ?B/s]
# test/mmlu_KO-KR.csv:   0%|          | 0.00/7.67M [00:00<?, ?B/s]
# test/mmlu_PT-BR.csv:   0%|          | 0.00/7.21M [00:00<?, ?B/s]
# test/mmlu_SW-KE.csv:   0%|          | 0.00/6.89M [00:00<?, ?B/s]
# test/mmlu_YO-NG.csv:   0%|          | 0.00/8.92M [00:00<?, ?B/s]
# test/mmlu_ZH-CN.csv:   0%|          | 0.00/5.58M [00:00<?, ?B/s]
# ...

# %%
dataset
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['Unnamed: 0', 'Question', 'A', 'B', 'C', 'D', 'Answer', 'Subject'],
#         num_rows: 196588
#     })
# })

# %%
dataset['test'].to_pandas().head(50)
# Out:
#     Unnamed: 0                                           Question  \
# 0           81  Seorang peneliti sedang mempelajari insiden fl...
# 1           50  सकारात्मक कार्रवाई में किसी संगठन के कार्यबल क...
# 2           48  本问题涉及以下信息。\n“今天，这个国家一半的人完全无力从成文法上抹去一部不公正的法律，或在...
# 3           43  As estruturas que agem como locais de troca ga...
# 4           99  사적 유물론’(historical materialism, HM)이라는 용어의 정의와...
# 5          236  কীভাবে মার্কিন যুক্তরাষ্ট্র এবং ইউরোপে নিরাপত্...
# 6          232  Ipi kati ya zifuatazo ni sifa za ushindani wa ...
# 7          274  La diagnosi di carenza di ferro può essere com...
# 8           41  当无线用户向任何 AP 进行身份验证时，他们都会经历四步身份验证过程，称为 ________...
# 9          285  أي من العبارات التالية صحيحة حول الحالة الغذائ...
# 10          34  Une balle de baseball est lancée verticalement...
# 11         102  54,321 का सबसे बड़ा गुणनखंड क्या है जो 54,321 ...
# 12         719  كاتبة تمتلك مبنى في مدينة. كانت هذه هي القطعة ...
# ...

# %%
dataset = dataset['test'].train_test_split(test_size = 0.1, seed = 42)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['Unnamed: 0', 'Question', 'A', 'B', 'C', 'D', 'Answer', 'Subject'],
#         num_rows: 176929
#     })
#     test: Dataset({
#         features: ['Unnamed: 0', 'Question', 'A', 'B', 'C', 'D', 'Answer', 'Subject'],
#         num_rows: 19659
#     })
# })

# %%
train_dataset = dataset['train']
test_dataset = dataset['test']
train_dataset
# Out:
# Dataset({
#     features: ['Unnamed: 0', 'Question', 'A', 'B', 'C', 'D', 'Answer', 'Subject'],
#     num_rows: 176929
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['Unnamed: 0', 'Question', 'A', 'B', 'C', 'D', 'Answer', 'Subject'],
#     num_rows: 19659
# })
