# %% [markdown]
# <a href="https://colab.research.google.com/github/azzindani/00_HF_Dataset_Preview/blob/main/HF_Conversations_Email_Summaries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Modules

# %%
# !pip install datasets
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.7/472.7 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 10.2 MB/s eta 0:00:00
# ...

# %%
from datasets import load_dataset
from datasets import Dataset

# %% [markdown]
# ## Import Dataset

# %%
#url = 'https://huggingface.co/datasets/KingNish/reasoning-base-20k'
#dataset_name = url.split('datasets/')[-1]

dataset_name = 'argilla/FinePersonas-Conversations-Email-Summaries'

# %%
dataset = load_dataset(dataset_name)

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['conversation_id', 'email', 'maximum_brevity_summary', 'summary', 'distilabel_metadata', 'model_name'],
#         num_rows: 363584
#     })
# })

# %%
dataset['train'].select(range(50)).to_pandas().head(50)
# Out:
#     conversation_id                                              email  \
# 0                 0  Subject: Virtual Field Trip Collaboration\n\nH...
# 1                 0  Subject: RE: Virtual Field Trip Collaboration\...
# 2                 0  Subject: RE: Virtual Field Trip Collaboration\...
# 3                 1  Subject: Need some advice on teaching climate ...
# 4                 1  Subject: RE: Need some advice on teaching clim...
# 5                 1  Subject: RE: Need some advice on teaching clim...
# 6                 2  Subject: Exciting new resource and conference ...
# 7                 2  Subject: RE: Exciting new resource and confere...
# 8                 2  Subject: RE: Exciting new resource and confere...
# 9                 3  Subject: Collaborative Project on Geography, H...
# 10                3  Subject: RE: Collaborative Project on Geograph...
# 11                4  Subject: Help with a lesson plan?\n\nHey Emily...
# ...

# %%
dataset = dataset['train'].train_test_split(test_size = 0.1, seed = 42)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['conversation_id', 'email', 'maximum_brevity_summary', 'summary', 'distilabel_metadata', 'model_name'],
#         num_rows: 327225
#     })
#     test: Dataset({
#         features: ['conversation_id', 'email', 'maximum_brevity_summary', 'summary', 'distilabel_metadata', 'model_name'],
#         num_rows: 36359
#     })
# })

# %%
train_dataset = dataset['train']
test_dataset = dataset['test']
train_dataset
# Out:
# Dataset({
#     features: ['conversation_id', 'email', 'maximum_brevity_summary', 'summary', 'distilabel_metadata', 'model_name'],
#     num_rows: 327225
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['conversation_id', 'email', 'maximum_brevity_summary', 'summary', 'distilabel_metadata', 'model_name'],
#     num_rows: 36359
# })

# %%
dataset['train'][0]
# Out:
# {'conversation_id': 885,
#  'email': "Subject: RE: Coffee chat about your research?\n\nHi Neha,\n\nThat sounds great! I'm always happy to discuss my research, and I'm curious to hear more about your article as well. Saturday afternoon works well for me. How about we meet at the Green Leaf Café on Main Street? They have a nice space for conversations and often host community events.\n\nLet's say 2 pm? Just let me know if that works for you or if you have any other preferences.\n\nLooking forward to our chat!\n\nSanjay",
#  'maximum_brevity_summary': 'Sanjay agrees to meet at the Green Leaf Café on Main Street at 2 pm on Saturday to discuss research and an article.',
#  'summary': "Sanjay is happy to discuss research and is interested in hearing about the article. Sanjay suggests meeting at the Green Leaf Café on Main Street at 2 pm on Saturday, noting the café's suitability for conversations. Sanjay is awaiting confirmation on the time and place.",
# ...
