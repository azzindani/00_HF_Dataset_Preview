# %% [markdown]
# <a href="https://colab.research.google.com/github/azzindani/00_HF_Dataset_Preview/blob/main/HF_Dataset_Open_Math_Instruct_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Import Modules

# %%
# !pip install datasets

# %%
from datasets import load_dataset
from datasets import Dataset

# %% [markdown]
# ## Import Dataset

# %%
#url = 'https://huggingface.co/datasets/KingNish/reasoning-base-20k'
#dataset_name = url.split('datasets/')[-1]

dataset_name = 'nvidia/OpenMathInstruct-2'

# %%
dataset = load_dataset(dataset_name)
# Out:
# ...
# Loading dataset shards:   0%|          | 0/32 [00:00<?, ?it/s]

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['problem', 'generated_solution', 'expected_answer', 'problem_source'],
#         num_rows: 13972791
#     })
#     train_1M: Dataset({
#         features: ['problem', 'generated_solution', 'expected_answer', 'problem_source'],
#         num_rows: 1000000
#     })
#     train_2M: Dataset({
#         features: ['problem', 'generated_solution', 'expected_answer', 'problem_source'],
#         num_rows: 2000000
#     })
#     train_5M: Dataset({
#         features: ['problem', 'generated_solution', 'expected_answer', 'problem_source'],
#         num_rows: 5000000
#     })
# })

# %%
dataset['train_1M'].to_pandas().head(100)
# Out:
#                                               problem  \
# 0   Solve for $y$:\n\n$$\frac{y^2 - 3y + 2}{y - 2}...
# 1   Given a circle centered at the origin, a point...
# 2   The repeating decimal $0.\overline{009}$ can b...
# 3   Let $m$ and $n$ be two positive integers such ...
# 4   Let $(x, y)$ be a solution to the system of eq...
# ..                                                ...
# 95  At a family reunion, five adults and four chil...
# 96  Find the sum of the roots of all polynomials o...
# 97  If $0.8= \frac{y}{186+x}$, find the smallest v...
# 98  Lily's aloe vera plant produces 3 offsets 3 ti...
# 99  The operation $\diamond$ is defined as $a \dia...
#
#                                    generated_solution  \
# 0   Start by multiplying both sides by $y - 2$ to ...
# 1   The rotation matrix for rotating a point $(x, ...
# 2   To express $0.\overline{009}$ as a fraction, l...
# 3   ## Step 1: Recall the relationship between GCD...
# ...

# %%
dataset = dataset['train_1M'].train_test_split(test_size = 0.1, seed = 42)
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['problem', 'generated_solution', 'expected_answer', 'problem_source'],
#         num_rows: 900000
#     })
#     test: Dataset({
#         features: ['problem', 'generated_solution', 'expected_answer', 'problem_source'],
#         num_rows: 100000
#     })
# })

# %%
train_dataset = dataset['train']
test_dataset = dataset['test']
train_dataset
# Out:
# Dataset({
#     features: ['problem', 'generated_solution', 'expected_answer', 'problem_source'],
#     num_rows: 900000
# })

# %%
test_dataset
# Out:
# Dataset({
#     features: ['problem', 'generated_solution', 'expected_answer', 'problem_source'],
#     num_rows: 100000
# })
